# %%
# !pip install --upgrade pip
# !pip install nltk spacy pandas
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
import spacy
import pandas as pd
# Out:
# /Users/kevin/Documents/ai-engineer/nlp/.venv/lib/python3.14/site-packages/confection/__init__.py:38: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel, Extra, ValidationError, create_model
# /Users/kevin/Documents/ai-engineer/nlp/.venv/lib/python3.14/site-packages/pydantic/v1/schema.py:1022: UserWarning: On field "pattern" the following field constraints are set but not enforced: min_items.
# For more details see https://docs.pydantic.dev/usage/schema/#unenforced-field-constraints
#   warnings.warn(
# /Users/kevin/Documents/ai-engineer/nlp/.venv/lib/python3.14/site-packages/pydantic/v1/schema.py:1022: UserWarning: On field "checksum" the following field constraints are set but not enforced: regex.
# For more details see https://docs.pydantic.dev/usage/schema/#unenforced-field-constraints
#   warnings.warn(

# %%
nlp = spacy.load("en_core_web_sm")
nlp

# %%
paragraph = "Books are an important part of our life. We read many kinds of books. We study text books at school that are part of our syllabus. \nWe also have story books that we read for leisure and fun. We can get them from the school library. We can also buy them from bookshops. Books are printed on paper, and can have pictures too that make them interesting. We can read books on the computer as well. \nI love reading children’s stories published in colourful books, as they are beautifully presented. I have a nice collection of story books at home."
paragraph
# Out:
# 'Books are an important part of our life. We read many kinds of books. We study text books at school that are part of our syllabus. \nWe also have story books that we read for leisure and fun. We can get them from the school library. We can also buy them from bookshops. Books are printed on paper, and can have pictures too that make them interesting. We can read books on the computer as well. \nI love reading children’s stories published in colourful books, as they are beautifully presented. I have a nice collection of story books at home.'

# %%
spacy_doc = nlp(paragraph)
spacy_doc
# Out:
# Books are an important part of our life. We read many kinds of books. We study text books at school that are part of our syllabus.
# We also have story books that we read for leisure and fun. We can get them from the school library. We can also buy them from bookshops. Books are printed on paper, and can have pictures too that make them interesting. We can read books on the computer as well.
# I love reading children’s stories published in colourful books, as they are beautifully presented. I have a nice collection of story books at home.

# %%
pos_df = pd.DataFrame(columns=['Token', 'POS'])

# %%
for token in spacy_doc:
    # print(token)
    pos_df = pd.concat([pos_df,
                        pd.DataFrame.from_records([{'Token': token, 'POS': token.pos_}])], ignore_index=True)

# %%
pos_df.head(15)
# Out:
#         Token    POS
# 0       Books   NOUN
# 1         are    AUX
# 2          an    DET
# 3   important    ADJ
# 4        part   NOUN
# 5          of    ADP
# 6         our   PRON
# 7        life   NOUN
# 8           .  PUNCT
# 9          We   PRON
# 10       read   VERB
# 11       many    ADJ
# 12      kinds   NOUN
# 13         of    ADP
# 14      books   NOUN
