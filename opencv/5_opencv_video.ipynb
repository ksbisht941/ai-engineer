# %%
from IPython.display import display, clear_output
from PIL import Image
import cv2
import time

# %%
cap = cv2.VideoCapture(0)

print("Starting video stream... Click the 'Stop' button in the toolbar to end.")

try:
    while True:
        ret, frame = cap.read()

        if not ret:
            print("Failed to grab frame")
            break
        
        # Convert the frame from BGR to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Convert to PIL Image
        img = Image.fromarray(frame_rgb)
        
        # Display the image
        clear_output(wait=True)
        display(img)
        
        # Add a small sleep to prevent overwhelming the display
        time.sleep(0.01)
        
except KeyboardInterrupt:
    print("Interrupted by user")
finally:
    cap.release()
    print("Camera released.")
# Out:
# Interrupted by user
# Camera released.

# %%
cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
# Use 'avc1' or 'mp4v' for .mp4 on macOS, or 'XVID' for .avi
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

recoder = cv2.VideoWriter('output_video/output_video.mp4', fourcc, 20.0, (frame_width, frame_height))

print("Recording video... Click the 'Stop' button in the toolbar to end.")

try:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        # Write the frame to the file
        recoder.write(frame)

        # Convert the frame from BGR to RGB for display
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Convert to PIL Image
        img = Image.fromarray(frame_rgb)
        
        # Display the image in the notebook
        clear_output(wait=True)
        display(img)
        
        # Add a small sleep to prevent overwhelming the display
        time.sleep(0.01)
        
except KeyboardInterrupt:
    print("Recording stopped by user.")
finally:
    # Release everything when finished
    cap.release()
    out.release()
    print("Camera and VideoWriter released. File saved as 'output_video.avi'")
# Out:
# Recording stopped by user.
# Camera and VideoWriter released. File saved as 'output_video.avi'
